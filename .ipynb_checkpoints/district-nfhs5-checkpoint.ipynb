# %% [markdown]
# # National Family Health Survey, India - NFHS-5
#
# ### Web Scraping  -  District level

# %%
from bs4 import BeautifulSoup
import requests
import PyPDF2
import io
import re
import csv

# %%
def get_urls(url):
    pdf_list = []
    
    # Get HTML file from the given url
    html_doc = requests.get(url)
    
    # check the status of getting HTML file from url
    if html_doc.status_code == 200:
        # Create a beautiful soup object for the HTML file to manipulate and extract data from it.
        soup = BeautifulSoup(html_doc.text, 'html.parser')
        
        dropdown = soup.find("select")
        dropdown_values = dropdown.find_all(target="new")

        for i in dropdown_values:    
            pdf_list.append('http://rchiips.org/nfhs/'+ i['value'])
    
    return pdf_list

# %%
url = "http://rchiips.org/nfhs/districtfactsheet_NFHS-5.shtml"
state_urls = get_urls(url)

# %%
state_urls
# Out:
# ['http://rchiips.org/nfhs/NFHS-5_AP.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_AR.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_AS.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_BR.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_CT.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_GA.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_GJ.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_HR.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_HP.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_JH.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_KA.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_KL.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_MP.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_MH.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_MN.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_ML.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_MZ.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_NL.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_OR.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_PB.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_RJ.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_SK.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_TN.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_TL.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_TR.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_UP.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_UT.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_WB.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_AN.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_CH.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_DD.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_DL.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_JK.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_LH.shtml',
#  'http://rchiips.org/nfhs/NFHS-5_PY.shtml']

# %%
all_district_urls = []
for i in state_urls:   
    state_districts_list = get_urls(i)
    for j in state_districts_list:
        all_district_urls.append(j)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File e:\Anaconda3\envs\venv_nfhs\lib\http\client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File e:\Anaconda3\envs\venv_nfhs\lib\http\client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File e:\Anaconda3\envs\venv_nfhs\lib\http\client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File e:\Anaconda3\envs\venv_nfhs\lib\http\client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File e:\Anaconda3\envs\venv_nfhs\lib\http\client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000000000B467790>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='rchiips.org', port=80): Max retries exceeded with url: /nfhs/NFHS-5_AR.shtml (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000B467790>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 all_district_urls = []
#       2 for i in state_urls:
# ----> 3     state_districts_list = get_urls(i)
#       4     for j in state_districts_list:
#       5         all_district_urls.append(j)
#
# Input In [2], in get_urls(url)
#       2 pdf_list = []
#       4 # Get HTML file from the given url
# ----> 5 html_doc = requests.get(url)
#       7 # check the status of getting HTML file from url
#       8 if html_doc.status_code == 200:
#       9     # Create a beautiful soup object for the HTML file to manipulate and extract data from it.
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File e:\Anaconda3\envs\venv_nfhs\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='rchiips.org', port=80): Max retries exceeded with url: /nfhs/NFHS-5_AR.shtml (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000000000B467790>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))

# %%
all_district_urls
# Out:
# [['http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Anantapur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Chittoor.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/East Godavari.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Guntur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Krishna.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Kurnool.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Prakasam.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Sri Potti Sriramulu Nellore.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Srikakulam.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Visakhapatnam.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Vizianagaram.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/West Godavari.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AP/Y.S.R..pdf'],
#  ['http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Anjaw.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Changlang.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Dibang Valley.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/East Kameng.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/East Siang.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Kra Daadi.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Kurung Kumey.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Lohit.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Longding.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Lower Dibang Valley.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Lower Subansiri.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Namsai.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Papumpare.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Siang.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Tawang.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Tirap.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Upper Siang.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/Upper Subansiri.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/West Kameng.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AR/West Siang.pdf'],
#  ['http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Baksa.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Barpeta.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Biswanath.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Bongaigaon.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Cachar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Charaideo.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Chirang.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Darrang.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Dhemaji.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Dhubri.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Dibrugarh.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Dima Hasao.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Goalpara.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Golaghat.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Hailakandi.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Hojai.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Jorhat.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Kamrup.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Kamrup Metropolitan.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Karbi Anglong.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Karimganj.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Kokrajhar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Lakhimpur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Majuli.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Morigaon.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Nagaon.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Nalbari.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Sivasagar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Sonitpur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/South Salmara Mancachar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Tinsukia.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/Udalguri.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/AS/West Karbi Anglong.pdf'],
#  ['http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Araria.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Arwal.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Aurangabad.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Banka.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Begusarai.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Bhagalpur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Bhojpur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Buxar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Darbhanga.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Gaya.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Gopalganj.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Jamui.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Jehanabad.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Kaimur (Bhabua).pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Katihar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Khagaria.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Kishanganj.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Lakhisarai.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Madhepura.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Madhubani.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Munger.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Muzaffarpur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Nalanda.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Nawada.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Pashchim Champaran.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Patna.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Purba Champaran.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Purnia.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Rohtas.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Saharsa.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Samastipur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Saran.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Sheikhpura.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Sheohar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Sitamarhi.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Siwan.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Supaul.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/BR/Vaishali.pdf'],
#  ['http://rchiips.org/nfhs/NFHS-5_FCTS/CT/Balod.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/CT/Baloda Bazar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/CT/Balrampur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/CT/Bastar.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/CT/Bemetara.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/CT/Bijapur.pdf',
#   'http://rchiips.org/nfhs/NFHS-5_FCTS/CT/